# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('./data/Daftar_gaji.csv')

# %%
dataset.plot(x="Tahun_bekerja",y="Gaji",style='o')
plt.title('daftar gaji pegawai')
plt.xlabel('lama bekerja')
plt.ylabel('gaji')
plt.show()
